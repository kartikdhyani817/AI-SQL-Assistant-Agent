# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

API_KEY = "AQ.Ab8RN6KKTkvQgqdxAHWpLfORh_6ALQ4OHEfnt_8cPBBnXfkuCg"


genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
schema = """
Table: Customers

customer_id
customer_name
city

Table: Orders

order_id
customer_id
product
amount
order_date
"""

print(schema)
# Out:
# Table: Customers
#
# customer_id
# customer_name
# city
#
# Table: Orders
#
# order_id
# customer_id
# product
# amount
# order_date

# %%
user_question = """
Show all customers who spent more than 5000.
"""

# %%
prompt = f"""
You are an expert SQL Developer.

Database Schema:

{schema}

User Request:

{user_question}

Generate only the SQL query.
"""

# %%
response = model.generate_content(prompt)

generated_sql = response.text

print(generated_sql)
# Out:
# ```sql
# SELECT
#   c.customer_id,
#   c.customer_name,
#   c.city
# FROM Customers AS c
# JOIN Orders AS o
#   ON c.customer_id = o.customer_id
# GROUP BY
#   c.customer_id,
#   c.customer_name,
#   c.city
# HAVING
#   SUM(o.amount) > 5000;
# ```

# %%
with open(
    "generated_sql.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(generated_sql)

print("SQL Saved")
# Out:
# SQL Saved

# %%
explanation_prompt = f"""
You are an SQL instructor.

Explain the following SQL query in simple language.

SQL Query:

{generated_sql}

Explain:
1. What the query does
2. Tables used
3. Conditions used
4. Expected output
"""

# %%
explanation_response = model.generate_content(
    explanation_prompt
)

sql_explanation = explanation_response.text

print(sql_explanation)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4878.64ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2127.57ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3594.01ms
# Alright class, let's break down this SQL query step-by-step! Think of me as your guide through the wonderful world of databases.
#
# Here's the query again:
#
# ```sql
# SELECT
#   c.customer_id,
#   c.customer_name,
#   c.city
# FROM Customers AS c
# JOIN Orders AS o
#   ON c.customer_id = o.customer_id
# GROUP BY
#   c.customer_id,
#   c.customer_name,
#   c.city
# HAVING
#   SUM(o.amount) > 5000;
# ```
#
# ---
#
# ### 1. What the Query Does
#
# In simple terms, **this query is looking for your "high-roller" customers.**
#
# It's designed to find customers who have placed orders, and whose *total spending* across all their orders (the sum of all their order amounts) is greater than \$5000. For these special customers, it will then show you their ID, name, and the city they live in.
#
# Think of it like this: You want a list of your best customers who have spent a significant amount of money with you, so you can send them a special thank-you or a promotional offer.
#
# ### 2. Tables Used
#
# We're working with two tables here:
#
# *   **`Customers` (aliased as `c`)**: This table presumably holds information about each customer, like their unique ID, name, and city.
#     *   *(Imagine columns like: `customer_id`, `customer_name`, `city`, `email`)*
# *   **`Orders` (aliased as `o`)**: This table contains details about each order placed, including which customer placed it and the amount of the order.
#     *   *(Imagine columns like: `order_id`, `customer_id`, `order_date`, `amount`)*
#
# The `AS c` and `AS o` are just shorthand names (aliases) we give to the tables within this query, so we don't have to type out `Customers.` and `Orders.` every time we refer to a column from them. It makes the query cleaner and easier to read!
#
# ### 3. Conditions Used
#
# There are a few important conditions and clauses at play here:
#
# *   **`JOIN Orders AS o ON c.customer_id = o.customer_id`**:
#     *   This is our **linking condition**. It tells SQL to connect rows from the `Customers` table with rows from the `Orders` table *only when* the `customer_id` matches in both tables. This ensures we're only looking at orders that belong to a specific customer, and we're only considering customers who have actually placed at least one order.
# *   **`GROUP BY c.customer_id, c.customer_name, c.city`**:
#     *   This is a **grouping condition**. Before we can calculate a *total* for each customer, SQL needs to know how to group the orders. This clause tells SQL: "Put all the orders belonging to the *same customer* (identified by their ID, name, and city) into one logical group." This is essential for our next condition.
# *   **`HAVING SUM(o.amount) > 5000`**:
#     *   This is our **filtering condition for groups**. After SQL has grouped all the orders by customer and calculated the `SUM(o.amount)` (the total amount spent by each customer), this `HAVING` clause filters those *groups*. It says: "Only include those groups (i.e., those customers) where their total spending (`SUM(o.amount)`) is greater than \$5000."
#     *   **Important Note**: Notice we use `HAVING` here, not `WHERE`. `WHERE` is used to filter individual rows *before* any grouping or aggregation (like `SUM`) happens. `HAVING` is used to filter *groups* of rows *after* the aggregation has been calculated.
#
# ### 4. Expected Output
#
# The expected output will be a table with three columns:
#
# 1.  **`customer_id`**: The unique identifier for the customer.
# 2.  **`customer_name`**: The full name of the customer.
# 3.  **`city`**: The city where the customer lives.
#
# Each row in the output will represent **one distinct customer** who meets the criteria: they have placed at least one order, and the *total sum of all their order amounts combined* exceeds \$5000.
#
# **Example of Expected Output:**
#
# | customer\_id | customer\_name | city         |
# | :------------ | :------------- | :----------- |
# | 101           | Alice Smith    | New York     |
# | 205           | Bob Johnson    | Los Angeles  |
# | 310           | Carol White    | Chicago      |
# | *(...more customers)* | *(...)*        | *(...)*      |
#
# This query is a fantastic example of how we combine joining tables, grouping data, and applying conditions to find very specific insights from our database! Any questions?

# %%
with open(
    "sql_explanation.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(sql_explanation)

print("SQL Explanation Saved")
# Out:
# SQL Explanation Saved

# %%
optimization_prompt = f"""
You are a Senior SQL Performance Engineer.

Analyze the following SQL query.

SQL Query:

{generated_sql}

Provide:

1. Performance Issues
2. Optimization Suggestions
3. Index Recommendations
4. Better Version of Query
"""

# %%
optimization_response = model.generate_content(
    optimization_prompt
)

optimization_report = optimization_response.text

print(optimization_report)
# Out:
# As a Senior SQL Performance Engineer, I've analyzed the provided query. Here's a breakdown of its performance characteristics, potential issues, and optimization strategies.
#
# ## SQL Query Analysis
#
# ```sql
# SELECT
#   c.customer_id,
#   c.customer_name,
#   c.city
# FROM Customers AS c
# JOIN Orders AS o
#   ON c.customer_id = o.customer_id
# GROUP BY
#   c.customer_id,
#   c.customer_name,
#   c.city
# HAVING
#   SUM(o.amount) > 5000;
# ```
#
# ### 1. Performance Issues
#
# 1.  **Full Table Scans (Potential):** Without proper indexing, the database might perform full table scans on both `Customers` and `Orders` tables to execute the `JOIN` operation. This is highly inefficient for large tables.
# 2.  **Inefficient Join Operation:** The `JOIN` condition `c.customer_id = o.customer_id` relies heavily on efficient lookups. If `customer_id` is not indexed in `Orders`, finding matching orders for each customer can be very slow, potentially leading to nested loop joins that scan `Orders` repeatedly or requiring a costly hash/merge join on unsorted data.
# 3.  **Resource-Intensive Group By:** The `GROUP BY` clause requires the database to collect and aggregate all `Orders` records for each customer before filtering with `HAVING`. This can involve sorting a large intermediate result set or using hash tables, consuming significant CPU and memory resources, especially if there are many orders per customer or many distinct customers. If the intermediate data does not fit in memory, it may spill to disk, leading to heavy I/O.
# 4.  **Late Filtering with `HAVING`:** The `SUM(o.amount)` aggregation is performed for *all* groups (customers who have orders) *before* the `HAVING` clause filters them. This means the database calculates sums for customers whose total orders might be far less than 5000, only to discard those sums immediately afterward. This can lead to unnecessary computation.
# 5.  **Redundant Columns in `GROUP BY`:** While syntactically correct and often required by SQL standards, including `c.customer_name` and `c.city` in the `GROUP BY` when `c.customer_id` is a primary key (and thus unique) can theoretically add a slight overhead. Modern optimizers often recognize functional dependencies, but it still means the grouping operation has more columns to consider than strictly necessary for uniqueness if `customer_id` is the unique grouping key.
#
# ### 2. Optimization Suggestions
#
# 1.  **Implement Necessary Indexes:** This is the most crucial step. Proper indexes can transform full table scans into efficient index seeks.
# 2.  **Push Down Aggregation:** Consider performing the aggregation and filtering (`SUM` and `HAVING`) on the `Orders` table first in a subquery or CTE. This generates a smaller, pre-filtered result set (customer IDs and their total amounts) *before* joining with the `Customers` table. This reduces the number of rows processed by the outer join.
# 3.  **Minimize I/O and Data Movement:** By using covering indexes for the aggregation, the database might be able to compute sums directly from the index without accessing the base `Orders` table, further reducing I/O.
# 4.  **Analyze Execution Plan:** Always examine the database's execution plan (e.g., `EXPLAIN ANALYZE` in PostgreSQL, `EXPLAIN PLAN` in Oracle, `SET SHOWPLAN_ALL` in SQL Server) to understand exactly how the query is being executed and identify bottlenecks.
#
# ### 3. Index Recommendations
#
# 1.  **`Customers` Table:**
#     *   **`PRIMARY KEY (customer_id)`**: (Assumed to exist). This is essential for efficient lookups when joining from `Orders`. If `customer_id` is not the primary key, a unique index on `customer_id` is recommended.
#
# 2.  **`Orders` Table:**
#     *   **`INDEX (customer_id)`**: Absolutely critical for the `JOIN` operation. This allows the database to quickly locate all orders belonging to a specific customer without scanning the entire `Orders` table.
#     *   **`INDEX (customer_id, amount)`**: This is a **highly recommended composite covering index**.
#         *   It serves the `JOIN` condition on `customer_id`.
#         *   It facilitates the `GROUP BY` operation on `customer_id`.
#         *   It **covers** the `SUM(o.amount)` aggregation, meaning the database can calculate the sums directly from the index without needing to access the main `Orders` table data pages. This significantly reduces I/O.
#
# ### 4. Better Version of Query
#
# The most common and often performant optimization for this type of query is to perform the aggregation on the `Orders` table first in a subquery, filtering early, and then joining that pre-aggregated result with the `Customers` table. This approach generally leads to processing fewer rows in the join stage.
#
# ```sql
# SELECT
#   c.customer_id,
#   c.customer_name,
#   c.city
# FROM Customers AS c
# JOIN (
#   SELECT
#     o.customer_id,
#     SUM(o.amount) AS total_amount
#   FROM Orders AS o
#   GROUP BY
#     o.customer_id
#   HAVING
#     SUM(o.amount) > 5000
# ) AS CustomerOrderTotals
#   ON c.customer_id = CustomerOrderTotals.customer_id;
# ```
#
# **Explanation of Improvements in the Better Version:**
#
# *   **Early Aggregation and Filtering:** The inner subquery `CustomerOrderTotals` first calculates `SUM(o.amount)` for each `customer_id` and immediately applies the `HAVING SUM(o.amount) > 5000` filter. This means only `customer_id`s that meet the criteria (and their total amounts) are passed to the outer `JOIN`.
# *   **Reduced Join Data Volume:** The subquery produces a much smaller intermediate result set (one row per qualifying customer) compared to the original query where *all* individual order rows are first joined and then grouped.
# *   **Efficient Join with Pre-Aggregated Data:** The outer `JOIN` is now performed between the `Customers` table and a compact, pre-filtered list of customer IDs and their total amounts. This join is usually very fast, especially with the recommended indexes.
# *   **Clearer Execution Path:** This structure often guides the database optimizer to perform the aggregation on `Orders` first, which is typically more efficient.
#
# This refactored query, combined with the recommended indexes, should significantly improve performance, especially on large datasets.

# %%
with open(
    "sql_optimization_report.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(optimization_report)

print("Optimization Report Saved")
# Out:
# Optimization Report Saved

# %%
review_prompt = f"""
You are an SQL Code Reviewer.

Review the following SQL query.

SQL Query:

{generated_sql}

Provide:

1. Code Quality Score (out of 10)
2. Readability Review
3. Maintainability Review
4. Best Practice Suggestions
"""

# %%
review_response = model.generate_content(
    review_prompt
)

sql_review = review_response.text

print(sql_review)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 8658.05ms
# Here's a review of the provided SQL query:
#
# ---
#
# ### SQL Query Review
#
# **SQL Query:**
#
# ```sql
# SELECT
#   c.customer_id,
#   c.customer_name,
#   c.city
# FROM Customers AS c
# JOIN Orders AS o
#   ON c.customer_id = o.customer_id
# GROUP BY
#   c.customer_id,
#   c.customer_name,
#   c.city
# HAVING
#   SUM(o.amount) > 5000;
# ```
#
# ---
#
# ### 1. Code Quality Score: 9/10
#
# This is a well-structured and functionally correct query for its purpose. It follows standard SQL practices, uses clear aliases, and is formatted nicely. It loses a point for a few minor best practice considerations rather than any significant flaw.
#
# ---
#
# ### 2. Readability Review
#
# *   **Formatting:** Excellent. The consistent indentation, line breaks for clauses (`SELECT`, `FROM`, `JOIN`, `ON`, `GROUP BY`, `HAVING`), and alignment make it very easy to read and understand the query's structure at a glance.
# *   **Aliases:** Effective use of short, descriptive aliases (`c` for Customers, `o` for Orders) improves conciseness without sacrificing clarity.
# *   **Clarity of Intent:** The query's purpose is immediately clear: "Get the ID, name, and city of customers whose total order amount exceeds 5000."
# *   **Column Qualification:** All columns are correctly qualified with their table aliases (`c.customer_id`, `o.amount`), preventing ambiguity and improving clarity.
#
# ---
#
# ### 3. Maintainability Review
#
# *   **Simplicity:** The query uses fundamental SQL concepts (`JOIN`, `GROUP BY`, `HAVING`) in a straightforward manner. It doesn't involve overly complex subqueries or CTEs, making it easy for future developers to understand, modify, and debug.
# *   **Standard SQL:** It adheres to standard SQL syntax, meaning it's highly portable across different relational database systems (MySQL, PostgreSQL, SQL Server, Oracle, etc.).
# *   **Self-Documenting:** With clear table and column names (assuming they are descriptive in the schema), the query is largely self-documenting.
# *   **Modifiability:** If requirements change (e.g., different aggregation, different filtering threshold, adding more customer details), this query provides a solid and easily adaptable foundation.
#
# ---
#
# ### 4. Best Practice Suggestions
#
# 1.  **Explicit `JOIN` Type:** While `JOIN` defaults to `INNER JOIN` in most SQL dialects, explicitly stating `INNER JOIN` can sometimes improve readability and leave no doubt about the intention, especially for those less familiar with SQL nuances. In this specific case, `INNER JOIN` is indeed the correct choice as you only want customers who *have* placed orders.
#     ```sql
#     -- Suggestion: Be explicit with JOIN type
#     FROM Customers AS c
#     INNER JOIN Orders AS o
#       ON c.customer_id = o.customer_id
#     ```
#
# 2.  **Indexing for Performance:**
#     *   Ensure that `Customers.customer_id` is a primary key (and thus indexed).
#     *   Ensure that `Orders.customer_id` is indexed (it should be a foreign key, and foreign keys generally benefit greatly from indexes). This is crucial for the `JOIN` and `GROUP BY` operations.
#     *   An index on `Orders.amount` could potentially speed up the `SUM(o.amount)` aggregation, especially if the table is very large and the `GROUP BY` results in many rows being scanned for each group. However, the index on `Orders.customer_id` is likely more critical for overall performance.
#
# 3.  **Handling NULLs in `o.amount` (Conditional):** If `o.amount` *could* be `NULL` and a `NULL` amount should be treated as `0` for the sum, then `SUM(COALESCE(o.amount, 0))` would be safer. If `amount` is defined as `NOT NULL` in the schema or if `NULL` values should genuinely be ignored by the sum (which `SUM()` does by default), then the current approach is perfectly fine. This is an assumption based on schema design.
#
# 4.  **Magic Numbers:** The value `5000` is a "magic number." If this threshold is a business rule that might change or needs to be configurable, consider:
#     *   Passing it as a parameter if this is part of a stored procedure or function.
#     *   Storing it in a configuration table if it's a system-wide setting.
#     *   Using a CTE or variable (depending on SQL dialect) for clarity if the number is used multiple times or its meaning isn't immediately obvious. For a simple ad-hoc query, it's generally acceptable.
#
# 5.  **Ordering Results (Optional):** Depending on how the results will be used, adding an `ORDER BY` clause might be beneficial (e.g., `ORDER BY c.customer_name` or `ORDER BY SUM(o.amount) DESC`). This isn't a functional requirement but often improves usability of the output.
#
# ---

# %%
with open(
    "sql_review.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(sql_review)

print("SQL Review Saved")
# Out:
# SQL Review Saved

# %%
sql_query = """
SELECT customer_name
FROM Customers
WHERE amount > 5000
"""

# %%
error_prompt = f"""
You are an SQL expert.

Analyze the following SQL query.

Query:

{sql_query}

Provide:

1. Errors in the query
2. Why they occur
3. Correct version of query
"""

# %%
error_response = model.generate_content(error_prompt)

error_report = error_response.text

print(error_report)
# Out:
# You're absolutely right to question that query! As an SQL expert, I can tell you that the most significant issue lies in a common misunderstanding of typical relational database schema design.
#
# Let's break it down:
#
# ---
#
# ### Analysis of the Query:
#
# **Query:**
#
# ```sql
# SELECT customer_name
# FROM Customers
# WHERE amount > 5000
# ```
#
# ---
#
# ### 1. Errors in the query
#
# The primary "error" isn't strictly a syntax error that would prevent the query from running if the columns *did* exist, but rather a **semantic or schema-dependent error**.
#
# The most likely error you would encounter, depending on your specific SQL dialect and database schema, is:
#
# *   **`Invalid column name 'amount'.`** (SQL Server)
# *   **`Unknown column 'amount' in 'where clause'`** (MySQL)
# *   **`column "amount" does not exist`** (PostgreSQL)
# *   **`ORA-00904: "AMOUNT": invalid identifier`** (Oracle)
#
# ### 2. Why they occur
#
# This error occurs for the following reasons:
#
# 1.  **Typical Database Schema Design:** In a well-normalized relational database, a `Customers` table usually stores information *about the customers themselves*: `customer_id`, `customer_name`, `address`, `phone_number`, `email`, etc.
# 2.  **Location of Transactional Data:** An `amount` (presumably referring to a monetary value of an order, transaction, or sale) typically resides in a *separate table* that records these transactions, such as an `Orders` table, `Sales` table, or `Transactions` table. These tables would contain columns like `order_id`, `customer_id` (a foreign key linking back to `Customers`), `order_date`, `amount`, `product_id`, etc.
# 3.  **Missing Column:** The `Customers` table, in most standard designs, does not directly have an `amount` column. Therefore, when the `WHERE` clause tries to filter on `amount` directly from the `Customers` table, the database system cannot find that column in the specified table.
#
# While it's *possible* to have a denormalized `Customers` table with a column like `total_lifetime_spend` or `highest_single_order_amount`, it's not the default or most common design when an `amount` column is referenced in this way without aggregation. The query implies checking individual order amounts.
#
# ### 3. Correct version of query
#
# To correct this query, we need to make a reasonable assumption about the existence of related tables and how they link to the `Customers` table.
#
# **Assumption:** There is an `Orders` table that contains transaction details, including `amount` and a `customer_id` column to link to the `Customers` table.
#
# Here are a few correct versions, depending on the exact intent:
#
# **Scenario 1: Find customers who have placed at least one individual order with an amount greater than 5000.**
#
# This is the most direct interpretation of the original query's intent for a single `amount`.
#
# ```sql
# SELECT DISTINCT c.customer_name
# FROM Customers c
# JOIN Orders o ON c.customer_id = o.customer_id
# WHERE o.amount > 5000;
# ```
#
# **Explanation:**
# *   `FROM Customers c JOIN Orders o ON c.customer_id = o.customer_id`: This joins the `Customers` table (aliased as `c`) with the `Orders` table (aliased as `o`) using the common `customer_id` column.
# *   `WHERE o.amount > 5000`: This filters the joined results, looking for rows where the `amount` from the `Orders` table is greater than 5000.
# *   `SELECT DISTINCT c.customer_name`: We select the customer's name, using `DISTINCT` to ensure each customer is listed only once, even if they have multiple orders exceeding 5000.
#
# ---
#
# **Scenario 2 (Alternative using EXISTS): Find customers who have placed at least one individual order with an amount greater than 5000.**
# This is semantically equivalent to Scenario 1 but can sometimes be more efficient for checking existence.
#
# ```sql
# SELECT c.customer_name
# FROM Customers c
# WHERE EXISTS (
#     SELECT 1
#     FROM Orders o
#     WHERE o.customer_id = c.customer_id
#       AND o.amount > 5000
# );
# ```
#
# **Explanation:**
# *   The `EXISTS` clause checks if there is *any* record in the `Orders` table that matches the current customer (`o.customer_id = c.customer_id`) AND has an `amount` greater than 5000. If such a record exists, the customer's name is selected.
#
# ---
#
# **Scenario 3: Find customers whose *total spending across all their orders* exceeds 5000.**
#
# If the intent was to find "high-value" customers based on their cumulative spending, the query needs aggregation.
#
# ```sql
# SELECT c.customer_name, SUM(o.amount) AS total_spent
# FROM Customers c
# JOIN Orders o ON c.customer_id = o.customer_id
# GROUP BY c.customer_id, c.customer_name
# HAVING SUM(o.amount) > 5000;
# ```
#
# **Explanation:**
# *   `JOIN Orders o ON c.customer_id = o.customer_id`: Joins customers with their orders.
# *   `GROUP BY c.customer_id, c.customer_name`: Groups all orders by each customer.
# *   `HAVING SUM(o.amount) > 5000`: Filters these groups, keeping only those customers whose *sum* of all order amounts is greater than 5000.
# *   `SELECT c.customer_name, SUM(o.amount) AS total_spent`: Selects the customer's name and their calculated total spending.
#
# ---
#
# The correct version largely depends on the precise business question being asked, but all correct versions involve linking to an `Orders` or similar transactional table where `amount` is stored.

# %%
with open(
    "sql_error_report.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(error_report)

print("Error Report Saved")
# Out:
# Error Report Saved

# %%
practice_prompt = """
Generate:

1. 10 Beginner SQL Questions
2. 10 Intermediate SQL Questions
3. 5 Advanced SQL Questions

Include answers.
"""

# %%
practice_response = model.generate_content(
    practice_prompt
)

practice_questions = practice_response.text

print(practice_questions)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 18270.59ms
# Okay, here are SQL questions categorized by difficulty, along with a sample database schema and answers.
#
# ---
#
# ### Sample Database Schema
#
# We'll use a simple e-commerce database for these questions.
#
# **1. `Customers` Table**
# *   `customer_id` (INT, Primary Key)
# *   `first_name` (VARCHAR)
# *   `last_name` (VARCHAR)
# *   `email` (VARCHAR)
# *   `registration_date` (DATE)
# *   `city` (VARCHAR)
#
# **2. `Products` Table**
# *   `product_id` (INT, Primary Key)
# *   `product_name` (VARCHAR)
# *   `category` (VARCHAR)
# *   `price` (DECIMAL)
# *   `stock_quantity` (INT)
#
# **3. `Orders` Table**
# *   `order_id` (INT, Primary Key)
# *   `customer_id` (INT, Foreign Key to `Customers`)
# *   `order_date` (DATE)
# *   `total_amount` (DECIMAL)
#
# **4. `OrderItems` Table**
# *   `order_item_id` (INT, Primary Key)
# *   `order_id` (INT, Foreign Key to `Orders`)
# *   `product_id` (INT, Foreign Key to `Products`)
# *   `quantity` (INT)
# *   `price_at_purchase` (DECIMAL)
#
# ---
#
# ### 10 Beginner SQL Questions
#
# These questions focus on basic data retrieval, filtering, sorting, and simple aggregation.
#
# **Q1: Retrieve all customer information.**
# *   **Question:** Get all columns and rows from the `Customers` table.
# *   **Answer:**
#     ```sql
#     SELECT *
#     FROM Customers;
#     ```
#
# **Q2: List specific product details.**
# *   **Question:** Display the `product_name` and `price` of all products.
# *   **Answer:**
#     ```sql
#     SELECT product_name, price
#     FROM Products;
#     ```
#
# **Q3: Filter products by price.**
# *   **Question:** Find all products that have a price greater than 50.00.
# *   **Answer:**
#     ```sql
#     SELECT *
#     FROM Products
#     WHERE price > 50.00;
#     ```
#
# **Q4: Find customers from a specific city.**
# *   **Question:** List the `first_name`, `last_name`, and `email` of all customers who live in 'New York'.
# *   **Answer:**
#     ```sql
#     SELECT first_name, last_name, email
#     FROM Customers
#     WHERE city = 'New York';
#     ```
#
# **Q5: Order products by price.**
# *   **Question:** Retrieve all products, ordered by `price` from the lowest to the highest.
# *   **Answer:**
#     ```sql
#     SELECT *
#     FROM Products
#     ORDER BY price ASC;
#     ```
#
# **Q6: Count total number of products.**
# *   **Question:** How many distinct products are listed in the `Products` table?
# *   **Answer:**
#     ```sql
#     SELECT COUNT(product_id)
#     FROM Products;
#     ```
#
# **Q7: Calculate total stock quantity.**
# *   **Question:** What is the total `stock_quantity` across all products?
# *   **Answer:**
#     ```sql
#     SELECT SUM(stock_quantity)
#     FROM Products;
#     ```
#
# **Q8: Find the average product price.**
# *   **Question:** Calculate the average `price` of all products.
# *   **Answer:**
#     ```sql
#     SELECT AVG(price)
#     FROM Products;
#     ```
#
# **Q9: Filter by multiple conditions.**
# *   **Question:** Find products that are in the 'Electronics' category and have a `stock_quantity` less than 100.
# *   **Answer:**
#     ```sql
#     SELECT *
#     FROM Products
#     WHERE category = 'Electronics' AND stock_quantity < 100;
#     ```
#
# **Q10: Get the most recent orders.**
# *   **Question:** List the 5 most recent orders, showing `order_id`, `customer_id`, and `order_date`.
# *   **Answer:**
#     ```sql
#     SELECT order_id, customer_id, order_date
#     FROM Orders
#     ORDER BY order_date DESC
#     LIMIT 5; -- Use TOP 5 in SQL Server, or ROWNUM in Oracle
#     ```
#
# ---
#
# ### 10 Intermediate SQL Questions
#
# These questions involve joins, grouping data, subqueries, and more complex filtering.
#
# **Q1: List orders with customer names.**
# *   **Question:** Show `order_id`, `order_date`, `total_amount`, and the `first_name` and `last_name` of the customer for each order.
# *   **Answer:**
#     ```sql
#     SELECT
#         O.order_id,
#         O.order_date,
#         O.total_amount,
#         C.first_name,
#         C.last_name
#     FROM Orders AS O
#     JOIN Customers AS C
#         ON O.customer_id = C.customer_id;
#     ```
#
# **Q2: Find products ordered by a specific customer.**
# *   **Question:** List the names of all products purchased by the customer with `customer_id = 101`.
# *   **Answer:**
#     ```sql
#     SELECT DISTINCT P.product_name
#     FROM Products AS P
#     JOIN OrderItems AS OI
#         ON P.product_id = OI.product_id
#     JOIN Orders AS O
#         ON OI.order_id = O.order_id
#     WHERE O.customer_id = 101;
#     ```
#
# **Q3: Calculate total sales per product category.**
# *   **Question:** For each product `category`, calculate the total sum of `price` * `quantity` from `OrderItems` (representing total revenue for that category).
# *   **Answer:**
#     ```sql
#     SELECT
#         P.category,
#         SUM(OI.quantity * OI.price_at_purchase) AS total_category_revenue
#     FROM OrderItems AS OI
#     JOIN Products AS P
#         ON OI.product_id = P.product_id
#     GROUP BY P.category;
#     ```
#
# **Q4: Find customers who haven't placed any orders.**
# *   **Question:** List the `first_name` and `last_name` of customers who have not placed any orders.
# *   **Answer:**
#     ```sql
#     SELECT C.first_name, C.last_name
#     FROM Customers AS C
#     LEFT JOIN Orders AS O
#         ON C.customer_id = O.customer_id
#     WHERE O.order_id IS NULL;
#     ```
#
# **Q5: Determine the number of orders per customer.**
# *   **Question:** For each customer, count how many orders they have placed. Display `customer_id`, `first_name`, `last_name`, and the `number_of_orders`. Only include customers who have placed at least one order.
# *   **Answer:**
#     ```sql
#     SELECT
#         C.customer_id,
#         C.first_name,
#         C.last_name,
#         COUNT(O.order_id) AS number_of_orders
#     FROM Customers AS C
#     JOIN Orders AS O
#         ON C.customer_id = O.customer_id
#     GROUP BY C.customer_id, C.first_name, C.last_name
#     HAVING COUNT(O.order_id) > 0; -- HAVING is used to filter aggregated results
#     ```
#
# **Q6: Products with stock below average.**
# *   **Question:** Find `product_name` and `stock_quantity` for products whose `stock_quantity` is less than the overall average `stock_quantity` of all products.
# *   **Answer:**
#     ```sql
#     SELECT product_name, stock_quantity
#     FROM Products
#     WHERE stock_quantity < (SELECT AVG(stock_quantity) FROM Products);
#     ```
#
# **Q7: Customers with total spending over a certain amount.**
# *   **Question:** List the `first_name`, `last_name`, and `total_spent` for customers who have spent more than 500.00 across all their orders.
# *   **Answer:**
#     ```sql
#     SELECT
#         C.first_name,
#         C.last_name,
#         SUM(O.total_amount) AS total_spent
#     FROM Customers AS C
#     JOIN Orders AS O
#         ON C.customer_id = O.customer_id
#     GROUP BY C.customer_id, C.first_name, C.last_name
#     HAVING SUM(O.total_amount) > 500.00;
#     ```
#
# **Q8: Products in specific categories.**
# *   **Question:** Find products whose `category` is either 'Electronics' or 'Books'.
# *   **Answer:**
#     ```sql
#     SELECT product_name, category
#     FROM Products
#     WHERE category IN ('Electronics', 'Books');
#     ```
#
# **Q9: Orders placed in a specific month/year.**
# *   **Question:** Count the number of orders placed in January 2023.
# *   **Answer:**
#     ```sql
#     SELECT COUNT(order_id)
#     FROM Orders
#     WHERE YEAR(order_date) = 2023 AND MONTH(order_date) = 1;
#     -- Or for PostgreSQL: WHERE EXTRACT(YEAR FROM order_date) = 2023 AND EXTRACT(MONTH FROM order_date) = 1;
#     ```
#
# **Q10: Detailed order item information.**
# *   **Question:** For each item in an order, display `order_id`, `product_name`, `quantity`, and `price_at_purchase`.
# *   **Answer:**
#     ```sql
#     SELECT
#         OI.order_id,
#         P.product_name,
#         OI.quantity,
#         OI.price_at_purchase
#     FROM OrderItems AS OI
#     JOIN Products AS P
#         ON OI.product_id = P.product_id;
#     ```
#
# ---
#
# ### 5 Advanced SQL Questions
#
# These questions involve more complex concepts like Common Table Expressions (CTEs), window functions, and correlated subqueries.
#
# **Q1: Find the top 3 spending customers using a CTE.**
# *   **Question:** Identify the top 3 customers who have spent the most money in total. Display their `first_name`, `last_name`, and `total_spent`. Use a Common Table Expression (CTE).
# *   **Answer:**
#     ```sql
#     WITH CustomerSpending AS (
#         SELECT
#             C.customer_id,
#             C.first_name,
#             C.last_name,
#             SUM(O.total_amount) AS total_spent
#         FROM Customers AS C
#         JOIN Orders AS O
#             ON C.customer_id = O.customer_id
#         GROUP BY C.customer_id, C.first_name, C.last_name
#     )
#     SELECT
#         first_name,
#         last_name,
#         total_spent
#     FROM CustomerSpending
#     ORDER BY total_spent DESC
#     LIMIT 3; -- Use TOP 3 in SQL Server
#     ```
#
# **Q2: Determine the most expensive product in each category using a Window Function.**
# *   **Question:** For each product `category`, find the product with the highest price. Display the `category`, `product_name`, and `price`.
# *   **Answer:**
#     ```sql
#     WITH RankedProducts AS (
#         SELECT
#             product_name,
#             category,
#             price,
#             ROW_NUMBER() OVER (PARTITION BY category ORDER BY price DESC) AS rn
#         FROM Products
#     )
#     SELECT
#         category,
#         product_name,
#         price
#     FROM RankedProducts
#     WHERE rn = 1;
#     ```
#
# **Q3: Calculate a running total of orders for each customer using a Window Function.**
# *   **Question:** For a specific customer (e.g., `customer_id = 101`), calculate the running total of their `total_amount` spent, ordered by `order_date`. Display `order_id`, `order_date`, `total_amount`, and `running_total_spend`.
# *   **Answer:**
#     ```sql
#     SELECT
#         order_id,
#         order_date,
#         total_amount,
#         SUM(total_amount) OVER (PARTITION BY customer_id ORDER BY order_date ASC) AS running_total_spend
#     FROM Orders
#     WHERE customer_id = 101;
#     ```
#
# **Q4: Find customers who ordered all products from a specific category (e.g., 'Books').**
# *   **Question:** Identify `customer_id` and `first_name` of customers who have purchased *every* product that belongs to the 'Books' category.
# *   **Answer:**
#     ```sql
#     SELECT C.customer_id, C.first_name, C.last_name
#     FROM Customers C
#     WHERE NOT EXISTS (
#         -- Subquery to find a 'Books' product that the customer has NOT purchased
#         SELECT P.product_id
#         FROM Products P
#         WHERE P.category = 'Books'
#         AND NOT EXISTS (
#             SELECT 1
#             FROM Orders O
#             JOIN OrderItems OI ON O.order_id = OI.order_id
#             WHERE O.customer_id = C.customer_id
#             AND OI.product_id = P.product_id
#         )
#     );
#     ```
#
# **Q5: Analyze customer purchase frequency - first and second purchase year.**
# *   **Question:** Find customers who made their *first* ever purchase in 2023 and their *second* ever purchase in 2024. Display the `customer_id`, and the `order_id` of their first order (from 2023) and their second order (from 2024).
# *   **Answer:**
#     ```sql
#     WITH CustomerOrderRank AS (
#         SELECT
#             customer_id,
#             order_id,
#             order_date,
#             ROW_NUMBER() OVER (PARTITION BY customer_id ORDER BY order_date ASC) AS rn
#         FROM Orders
#     )
#     SELECT
#         cor1.customer_id,
#         cor1.order_id AS first_order_2023_id,
#         cor2.order_id AS second_order_2024_id
#     FROM CustomerOrderRank AS cor1
#     JOIN CustomerOrderRank AS cor2
#         ON cor1.customer_id = cor2.customer_id
#     WHERE
#         cor1.rn = 1 AND YEAR(cor1.order_date) = 2023
#         AND cor2.rn = 2 AND YEAR(cor2.order_date) = 2024;
#     ```

# %%
with open(
    "sql_practice_questions.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(practice_questions)

print("Questions Saved")
# Out:
# Questions Saved

# %%
interview_prompt = """
You are a Senior Data Analyst interviewer.

Generate:

1. Top 20 SQL Interview Questions
2. Detailed Answers
3. Difficulty Level
"""

# %%
interview_response = model.generate_content(
    interview_prompt
)

interview_questions = interview_response.text

print(interview_questions)
# Out:
# Okay, as a Senior Data Analyst interviewer, I'll focus on questions that go beyond just syntax. I'll look for understanding of performance, analytical thinking, problem-solving, and the ability to choose the right tool for the job.
#
# Here are 20 SQL interview questions, with detailed answers and difficulty levels, designed for a Senior Data Analyst role.
#
# ---
#
# ### **Scenario Setup: Database Schema**
#
# Let's assume we have the following tables:
#
# *   **`Employees`**:
#     *   `employee_id` (PK)
#     *   `first_name`
#     *   `last_name`
#     *   `department_id` (FK to `Departments`)
#     *   `manager_id` (Self-referencing FK to `Employees.employee_id`)
#     *   `salary`
#     *   `hire_date`
# *   **`Departments`**:
#     *   `department_id` (PK)
#     *   `department_name`
#     *   `location`
# *   **`Orders`**:
#     *   `order_id` (PK)
#     *   `customer_id` (FK to `Customers`)
#     *   `order_date`
#     *   `total_amount`
# *   **`Customers`**:
#     *   `customer_id` (PK)
#     *   `first_name`
#     *   `last_name`
#     *   `email`
#     *   `registration_date`
#     *   `city`
# *   **`Products`**:
#     *   `product_id` (PK)
#     *   `product_name`
#     *   `category`
#     *   `price`
# *   **`Order_Items`**:
#     *   `order_item_id` (PK)
#     *   `order_id` (FK to `Orders`)
#     *   `product_id` (FK to `Products`)
#     *   `quantity`
#     *   `item_price` (price at the time of order)
#
# ---
#
# ### **SQL Interview Questions & Answers**
#
# ---
#
# #### **Question 1: Departmental Salary Analysis**
#
# **Question:** Find the average salary for each department and list departments where the average salary is above the company-wide average.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | first_name | last_name | department_id | salary |
# |-------------|------------|-----------|---------------|--------|
# | 1           | Alice      | Smith     | 101           | 60000  |
# | 2           | Bob        | Johnson   | 102           | 75000  |
# | 3           | Charlie    | Brown     | 101           | 65000  |
# | 4           | Diana      | Prince    | 103           | 90000  |
# | 5           | Eve        | Adams     | 102           | 80000  |
# | 6           | Frank      | White     | 101           | 70000  |
#
# **`Departments`**
# | department_id | department_name |
# |---------------|-----------------|
# | 101           | Sales           |
# | 102           | Marketing       |
# | 103           | Engineering     |
#
# **Answer:**
#
# ```sql
# SELECT
#     d.department_name,
#     AVG(e.salary) AS average_department_salary
# FROM
#     Employees e
# JOIN
#     Departments d ON e.department_id = d.department_id
# GROUP BY
#     d.department_name
# HAVING
#     AVG(e.salary) > (SELECT AVG(salary) FROM Employees);
# ```
#
# **Explanation:**
# 1.  **`SELECT d.department_name, AVG(e.salary) AS average_department_salary`**: We select the department name and calculate the average salary for each group.
# 2.  **`FROM Employees e JOIN Departments d ON e.department_id = d.department_id`**: We join `Employees` with `Departments` to get the department names.
# 3.  **`GROUP BY d.department_name`**: This aggregates the salaries by department.
# 4.  **`HAVING AVG(e.salary) > (SELECT AVG(salary) FROM Employees)`**: This is the crucial part. After calculating the average salary for each department, we filter these groups. The `HAVING` clause uses a subquery `(SELECT AVG(salary) FROM Employees)` to get the overall company average salary, and then compares each department's average against it. This demonstrates the use of `HAVING` with an aggregated value and a subquery.
#
# ---
#
# #### **Question 2: Top N Products by Sales Volume in Each Category**
#
# **Question:** For each product category, find the top 3 products with the highest total quantity sold. List the category, product name, and total quantity sold.
#
# **Difficulty:** Hard
#
# **Sample Data (partial):**
#
# **`Products`**
# | product_id | product_name | category    |
# |------------|--------------|-------------|
# | 1          | Laptop A     | Electronics |
# | 2          | Mouse X      | Electronics |
# | 3          | Keyboard Y   | Electronics |
# | 4          | Phone S      | Electronics |
# | 5          | Book P       | Books       |
# | 6          | Magazine Q   | Books       |
# | 7          | Pen R        | Stationery  |
#
# **`Order_Items`**
# | order_item_id | order_id | product_id | quantity |
# |---------------|----------|------------|----------|
# | 1             | 1001     | 1          | 2        |
# | 2             | 1001     | 2          | 1        |
# | 3             | 1002     | 1          | 3        |
# | 4             | 1002     | 3          | 1        |
# | 5             | 1003     | 5          | 5        |
# | 6             | 1004     | 2          | 2        |
# | 7             | 1004     | 4          | 1        |
# | 8             | 1005     | 5          | 2        |
# | 9             | 1006     | 6          | 4        |
#
# **Answer:**
#
# ```sql
# WITH ProductSales AS (
#     SELECT
#         p.category,
#         p.product_name,
#         SUM(oi.quantity) AS total_quantity_sold
#     FROM
#         Order_Items oi
#     JOIN
#         Products p ON oi.product_id = p.product_id
#     GROUP BY
#         p.category, p.product_name
# ),
# RankedProductSales AS (
#     SELECT
#         category,
#         product_name,
#         total_quantity_sold,
#         ROW_NUMBER() OVER (PARTITION BY category ORDER BY total_quantity_sold DESC) AS rn
#     FROM
#         ProductSales
# )
# SELECT
#     category,
#     product_name,
#     total_quantity_sold
# FROM
#     RankedProductSales
# WHERE
#     rn <= 3
# ORDER BY
#     category, total_quantity_sold DESC;
# ```
#
# **Explanation:**
# 1.  **`ProductSales` CTE**:
#     *   Calculates the `total_quantity_sold` for each `product_name` within its `category`.
#     *   This is achieved by joining `Order_Items` and `Products` and then `GROUP BY` category and product name.
# 2.  **`RankedProductSales` CTE**:
#     *   Applies a window function `ROW_NUMBER()` to assign a rank to each product within its `category`.
#     *   `PARTITION BY category` ensures the ranking restarts for each category.
#     *   `ORDER BY total_quantity_sold DESC` ranks products from highest to lowest quantity sold.
# 3.  **Final `SELECT` statement**:
#     *   Filters the `RankedProductSales` to include only those products where `rn` (rank) is 3 or less, effectively giving us the top 3 for each category.
#     *   Orders the final result for readability.
#
# ---
#
# #### **Question 3: Customers Who Haven't Placed an Order in the Last 6 Months**
#
# **Question:** Identify customers who have registered but have not placed any orders in the last 6 months.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name | registration_date |
# |-------------|------------|-------------------|
# | 1           | John       | 2023-01-01        |
# | 2           | Jane       | 2023-03-15        |
# | 3           | Mike       | 2023-02-10        |
# | 4           | Sarah      | 2023-08-01        |
#
# **`Orders`** (Assume `CURRENT_DATE` is '2024-01-10')
# | order_id | customer_id | order_date |
# |----------|-------------|------------|
# | 101      | 1           | 2023-11-01 |
# | 102      | 2           | 2023-05-20 |
# | 103      | 3           | 2023-07-15 |
# | 104      | 1           | 2023-04-01 |
# | 105      | 4           | 2023-12-01 |
#
# **Answer (using `NOT EXISTS`):**
#
# ```sql
# SELECT
#     c.customer_id,
#     c.first_name,
#     c.last_name,
#     c.email
# FROM
#     Customers c
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM Orders o
#     WHERE o.customer_id = c.customer_id
#       AND o.order_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 6 MONTH) -- MySQL syntax
#       -- OR o.order_date >= CURRENT_DATE - INTERVAL '6 months' -- PostgreSQL syntax
#       -- OR o.order_date >= DATEADD(month, -6, GETDATE()) -- SQL Server syntax
# );
# ```
#
# **Answer (using `LEFT JOIN` and `WHERE IS NULL`):**
#
# ```sql
# SELECT
#     c.customer_id,
#     c.first_name,
#     c.last_name,
#     c.email
# FROM
#     Customers c
# LEFT JOIN
#     (SELECT DISTINCT customer_id FROM Orders WHERE order_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 6 MONTH)) AS RecentOrders
#     ON c.customer_id = RecentOrders.customer_id
# WHERE
#     RecentOrders.customer_id IS NULL;
# ```
#
# **Explanation:**
# 1.  **`NOT EXISTS` approach:**
#     *   The outer query selects all customer details.
#     *   The `WHERE NOT EXISTS` clause checks if there is *no* matching record in the `Orders` table for the current customer (`o.customer_id = c.customer_id`) AND if that order's `order_date` is within the last 6 months.
#     *   `DATE_SUB(CURRENT_DATE(), INTERVAL 6 MONTH)` (or equivalent for other SQL dialects) calculates the date 6 months ago from today.
#     *   This approach is often more performant than `NOT IN` for large datasets as `EXISTS` can short-circuit.
# 2.  **`LEFT JOIN` approach:**
#     *   We `LEFT JOIN` `Customers` with a subquery that identifies customers who *have* placed an order in the last 6 months (`RecentOrders`).
#     *   If a customer from the `Customers` table doesn't have a matching record in `RecentOrders`, the columns from `RecentOrders` will be `NULL`.
#     *   `WHERE RecentOrders.customer_id IS NULL` filters for exactly these customers, meaning they haven't placed an order in the specified period.
#     *   Using `DISTINCT customer_id` in the subquery can help performance by reducing the number of rows to join against, though the optimizer might handle this automatically.
#
# ---
#
# #### **Question 4: Employee Hierarchy (Recursive CTE)**
#
# **Question:** List all employees and their direct manager, and if available, their manager's manager, and so on, up to the top-level manager (who has a `NULL` manager_id). Display employee name, manager name, and their level in the hierarchy (e.g., CEO is level 1).
#
# **Difficulty:** Hard
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | first_name | last_name | manager_id |
# |-------------|------------|-----------|------------|
# | 1           | John       | Doe       | NULL       | -- CEO
# | 2           | Jane       | Smith     | 1          | -- Manager 1
# | 3           | Peter      | Jones     | 2          | -- Employee 1.1
# | 4           | Sarah      | Brown     | 2          | -- Employee 1.2
# | 5           | Michael    | Green     | 1          | -- Manager 2
# | 6           | Emily      | White     | 5          | -- Employee 2.1
#
# **Answer:**
#
# ```sql
# WITH EmployeeHierarchy AS (
#     -- Anchor Member: Top-level managers (CEO)
#     SELECT
#         e.employee_id,
#         e.first_name || ' ' || e.last_name AS employee_name,
#         e.manager_id,
#         NULL AS manager_name,
#         1 AS level
#     FROM
#         Employees e
#     WHERE
#         e.manager_id IS NULL
#
#     UNION ALL
#
#     -- Recursive Member: Find direct reports
#     SELECT
#         e.employee_id,
#         e.first_name || ' ' || e.last_name AS employee_name,
#         e.manager_id,
#         eh.employee_name AS manager_name,
#         eh.level + 1 AS level
#     FROM
#         Employees e
#     JOIN
#         EmployeeHierarchy eh ON e.manager_id = eh.employee_id
# )
# SELECT
#     eh.employee_name,
#     eh.manager_name,
#     eh.level
# FROM
#     EmployeeHierarchy eh
# ORDER BY
#     eh.level, eh.employee_name;
# ```
#
# **Explanation:**
# This uses a **Recursive Common Table Expression (CTE)**, a powerful feature for hierarchical data.
# 1.  **`EmployeeHierarchy AS (...)`**: Defines the recursive CTE.
# 2.  **Anchor Member**:
#     *   The first `SELECT` statement (before `UNION ALL`) is the non-recursive part. It selects the top-level employees (CEOs) who have `NULL` in their `manager_id` column.
#     *   It initializes their `level` as 1.
# 3.  **`UNION ALL`**: Combines the anchor member with the recursive member.
# 4.  **Recursive Member**:
#     *   The second `SELECT` statement references the CTE itself (`EmployeeHierarchy eh`).
#     *   It joins `Employees e` with `EmployeeHierarchy eh` where `e.manager_id` matches `eh.employee_id`. This means it finds employees whose manager is already in the `EmployeeHierarchy` results.
#     *   For each found employee, it calculates their `level` as `eh.level + 1`.
#     *   `eh.employee_name AS manager_name` fetches the manager's name from the `EmployeeHierarchy` results.
# 5.  **Final `SELECT`**: Retrieves the data from the CTE and orders it by level and employee name for clear visualization of the hierarchy.
#
# ---
#
# #### **Question 5: Daily Running Total of Orders**
#
# **Question:** Calculate the running total of `total_amount` for orders, ordered by `order_date`.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Orders`**
# | order_id | order_date | total_amount |
# |----------|------------|--------------|
# | 101      | 2023-01-01 | 100.00       |
# | 102      | 2023-01-02 | 150.00       |
# | 103      | 2023-01-02 | 50.00        |
# | 104      | 2023-01-03 | 200.00       |
# | 105      | 2023-01-04 | 75.00        |
#
# **Answer:**
#
# ```sql
# SELECT
#     order_id,
#     order_date,
#     total_amount,
#     SUM(total_amount) OVER (ORDER BY order_date, order_id) AS running_total
# FROM
#     Orders
# ORDER BY
#     order_date, order_id;
# ```
#
# **Explanation:**
# 1.  **`SUM(total_amount) OVER (ORDER BY order_date, order_id)`**: This is a window function.
#     *   `SUM(total_amount)` specifies the aggregation.
#     *   `OVER (ORDER BY order_date, order_id)` defines the window. It tells SQL to apply the `SUM` function over all rows *up to and including the current row*, as defined by the ordering. The `order_id` is included in `ORDER BY` to ensure a deterministic order for orders placed on the same day.
#     *   This is a common and efficient way to calculate running totals in SQL.
#
# ---
#
# #### **Question 6: Identify Duplicate Emails in Customers Table**
#
# **Question:** Find all customer `email` addresses that appear more than once in the `Customers` table, along with the count of how many times each duplicate email appears.
#
# **Difficulty:** Easy
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name | email                |
# |-------------|------------|----------------------|
# | 1           | John       | john.doe@example.com |
# | 2           | Jane       | jane.smith@example.com |
# | 3           | Mike       | john.doe@example.com |
# | 4           | Sarah      | sarah.k@example.com  |
# | 5           | Peter      | jane.smith@example.com |
#
# **Answer:**
#
# ```sql
# SELECT
#     email,
#     COUNT(customer_id) AS email_count
# FROM
#     Customers
# GROUP BY
#     email
# HAVING
#     COUNT(customer_id) > 1;
# ```
#
# **Explanation:**
# 1.  **`SELECT email, COUNT(customer_id) AS email_count`**: We want to see the email address and how many times it appears.
# 2.  **`FROM Customers`**: Our source table.
# 3.  **`GROUP BY email`**: This groups all rows that have the same email address together.
# 4.  **`HAVING COUNT(customer_id) > 1`**: After grouping, we filter these groups. The `HAVING` clause allows us to filter on aggregated values. Here, we only keep groups where the count of customers for that email is greater than 1, indicating a duplicate.
#
# ---
#
# #### **Question 7: Total Sales Per Customer Per Month**
#
# **Question:** Calculate the total sales (`total_amount`) for each customer for each month, even if a customer had no sales in a particular month (show 0 for no sales). Display `customer_id`, `month`, and `total_sales`.
#
# **Difficulty:** Hard
#
# **Sample Data (partial):** (Assume orders range from '2023-01-01' to '2023-03-31')
#
# **`Customers`**
# | customer_id | first_name |
# |-------------|------------|
# | 1           | Alice      |
# | 2           | Bob        |
#
# **`Orders`**
# | order_id | customer_id | order_date | total_amount |
# |----------|-------------|------------|--------------|
# | 101      | 1           | 2023-01-15 | 100.00       |
# | 102      | 1           | 2023-03-01 | 50.00        |
# | 103      | 2           | 2023-01-20 | 200.00       |
#
# **Answer:**
#
# ```sql
# WITH AllMonths AS (
#     -- Generate all unique months present in orders
#     SELECT DISTINCT
#         DATE_TRUNC('month', order_date) AS month_start
#     FROM
#         Orders
# ),
# CustomerMonths AS (
#     -- Cross Join customers with all relevant months
#     SELECT
#         c.customer_id,
#         am.month_start
#     FROM
#         Customers c
#     CROSS JOIN
#         AllMonths am
# )
# SELECT
#     cm.customer_id,
#     TO_CHAR(cm.month_start, 'YYYY-MM') AS sales_month, -- Adjust format for your DB (e.g., FORMAT(cm.month_start, 'yyyy-MM') for SQL Server)
#     COALESCE(SUM(o.total_amount), 0) AS total_sales
# FROM
#     CustomerMonths cm
# LEFT JOIN
#     Orders o ON cm.customer_id = o.customer_id
#               AND DATE_TRUNC('month', o.order_date) = cm.month_start
# GROUP BY
#     cm.customer_id, cm.month_start
# ORDER BY
#     cm.customer_id, cm.month_start;
# ```
#
# **Explanation:**
# This problem requires generating missing combinations of customers and months, which is a common analytical challenge.
# 1.  **`AllMonths` CTE**:
#     *   Extracts the start of the month (`DATE_TRUNC('month', order_date)` for PostgreSQL/MySQL, `DATEADD(month, DATEDIFF(month, 0, order_date), 0)` for SQL Server) from all order dates.
#     *   `DISTINCT` ensures we get each unique month once.
# 2.  **`CustomerMonths` CTE**:
#     *   Performs a `CROSS JOIN` between all `Customers` and all `AllMonths`. This generates every possible combination of customer and month within the period covered by the orders. This is key for showing 0 sales for inactive months.
# 3.  **Final `SELECT` statement**:
#     *   `LEFT JOIN` `CustomerMonths` with `Orders`. This is crucial: if a customer had no orders in a specific month, `o.total_amount` will be `NULL`.
#     *   The join condition also matches `customer_id` and ensures the `order_date` falls within the `month_start`.
#     *   `COALESCE(SUM(o.total_amount), 0)`: If `SUM(o.total_amount)` is `NULL` (meaning no orders for that customer in that month), `COALESCE` replaces it with `0`. Otherwise, it returns the sum.
#     *   `GROUP BY` `customer_id` and `month_start` to aggregate sales for each customer-month pair.
#     *   `TO_CHAR` (or `FORMAT` for SQL Server, `DATE_FORMAT` for MySQL) is used to format the `month_start` into a 'YYYY-MM' string for display.
#
# ---
#
# #### **Question 8: Pivot Product Categories by Monthly Sales (Conceptual/Advanced)**
#
# **Question:** Transform the `Orders` and `Order_Items` data to show total sales (`quantity * item_price`) for each product `category` as separate columns, aggregated monthly.
#
# **Difficulty:** Hard (Conceptual, syntax varies)
#
# **Sample Data (partial):** (Assume orders from 2023-01 to 2023-02)
#
# **`Products`**
# | product_id | category    |
# |------------|-------------|
# | 1          | Electronics |
# | 2          | Books       |
# | 3          | Home        |
#
# **`Order_Items`**
# | order_id | product_id | quantity | item_price |
# |----------|------------|----------|------------|
# | 101      | 1          | 2        | 50.00      |
# | 102      | 2          | 1        | 25.00      |
# | 103      | 1          | 1        | 50.00      |
# | 104      | 3          | 3        | 10.00      |
#
# **`Orders`**
# | order_id | order_date |
# |----------|------------|
# | 101      | 2023-01-10 |
# | 102      | 2023-01-15 |
# | 103      | 2023-02-05 |
# | 104      | 2023-02-10 |
#
# **Answer (using `CASE WHEN` for pivoting, common across DBs):**
#
# ```sql
# SELECT
#     TO_CHAR(o.order_date, 'YYYY-MM') AS sales_month, -- PostgreSQL/Oracle
#     -- DATE_FORMAT(o.order_date, '%Y-%m') AS sales_month, -- MySQL
#     -- FORMAT(o.order_date, 'yyyy-MM') AS sales_month, -- SQL Server
#     SUM(CASE WHEN p.category = 'Electronics' THEN oi.quantity * oi.item_price ELSE 0 END) AS TotalSales_Electronics,
#     SUM(CASE WHEN p.category = 'Books' THEN oi.quantity * oi.item_price ELSE 0 END) AS TotalSales_Books,
#     SUM(CASE WHEN p.category = 'Home' THEN oi.quantity * oi.item_price ELSE 0 END) AS TotalSales_Home,
#     -- Add more categories as needed or dynamically generate them for a real solution
#     SUM(oi.quantity * oi.item_price) AS TotalSales_Overall
# FROM
#     Orders o
# JOIN
#     Order_Items oi ON o.order_id = oi.order_id
# JOIN
#     Products p ON oi.product_id = p.product_id
# GROUP BY
#     sales_month
# ORDER BY
#     sales_month;
# ```
#
# **Explanation:**
# 1.  **Joins**: We join `Orders`, `Order_Items`, and `Products` to get order dates, quantities, item prices, and product categories.
# 2.  **`GROUP BY sales_month`**: Aggregates the data monthly. `TO_CHAR(o.order_date, 'YYYY-MM')` extracts the year and month.
# 3.  **`SUM(CASE WHEN ... THEN ... ELSE 0 END)`**: This is the core of manual pivoting.
#     *   For each desired category (e.g., 'Electronics'), a `CASE` statement checks if the `category` matches.
#     *   If it matches, it adds the `quantity * item_price` (which is the sales for that item) to the sum for that column.
#     *   If it doesn't match, it adds `0`, ensuring it doesn't affect the sum for other categories.
#     *   This effectively creates new columns (`TotalSales_Electronics`, `TotalSales_Books`, etc.) where the sum for each category is calculated independently.
# 4.  **`TotalSales_Overall`**: An optional column to show the total sales across all categories for that month.
#
# **Note for interview:** For a truly dynamic pivot (where categories aren't known beforehand), you'd need to explain that it typically requires dynamic SQL (constructing the query string in an application language or stored procedure) as standard SQL doesn't support dynamic column names directly. Some databases like SQL Server have a `PIVOT` clause, but the `CASE WHEN` approach is more portable.
#
# ---
#
# #### **Question 9: Find Second Highest Salary**
#
# **Question:** Find the second highest salary among all employees. If there's no second highest, return NULL.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | salary |
# |-------------|--------|
# | 1           | 60000  |
# | 2           | 75000  |
# | 3           | 65000  |
# | 4           | 90000  |
# | 5           | 80000  |
# | 6           | 75000  |
#
# **Answer (using `DENSE_RANK()`):**
#
# ```sql
# WITH RankedSalaries AS (
#     SELECT
#         salary,
#         DENSE_RANK() OVER (ORDER BY salary DESC) AS rnk
#     FROM
#         Employees
# )
# SELECT
#     MAX(salary) AS second_highest_salary -- Use MAX in case multiple employees have the same 2nd highest salary
# FROM
#     RankedSalaries
# WHERE
#     rnk = 2;
# ```
#
# **Answer (using Subquery with `DISTINCT` and `LIMIT`/`OFFSET` - MySQL/PostgreSQL):**
#
# ```sql
# SELECT
#     salary
# FROM
#     Employees
# ORDER BY
#     salary DESC
# LIMIT 1 OFFSET 1;
# ```
#
# **Answer (using Subquery with `DISTINCT` and `TOP`/`ROW_NUMBER()` - SQL Server):**
#
# ```sql
# SELECT TOP 1 salary
# FROM (
#     SELECT DISTINCT TOP 2 salary
#     FROM Employees
#     ORDER BY salary DESC
# ) AS TopTwoSalaries
# ORDER BY salary ASC;
# ```
#
# **Explanation:**
# 1.  **`DENSE_RANK()` approach**:
#     *   `DENSE_RANK() OVER (ORDER BY salary DESC)` assigns a rank to each unique salary, with no gaps in ranking if there are ties. The highest salary gets rank 1, the next distinct salary gets rank 2, and so on.
#     *   The CTE `RankedSalaries` stores these ranks.
#     *   The final `SELECT` filters for `rnk = 2` and takes the `MAX(salary)` to handle cases where multiple employees share the second highest salary. This is the most robust and generally preferred method for its clarity and handling of ties.
# 2.  **`LIMIT`/`OFFSET` (MySQL/PostgreSQL)**:
#     *   `SELECT DISTINCT salary` ensures we only consider unique salary values.
#     *   `ORDER BY salary DESC` sorts salaries from highest to lowest.
#     *   `LIMIT 1 OFFSET 1` retrieves exactly one row, skipping the first (highest) one. This gives us the second highest.
# 3.  **`TOP`/`ROW_NUMBER()` (SQL Server)**:
#     *   The inner `SELECT DISTINCT TOP 2 salary ORDER BY salary DESC` gets the two highest distinct salaries.
#     *   The outer `SELECT TOP 1 salary ORDER BY salary ASC` then selects the lowest of these two (which will be the second highest overall).
#
# ---
#
# #### **Question 10: Difference in Salary from Previous Employee in Department**
#
# **Question:** For each employee, calculate the difference between their salary and the salary of the employee who was hired immediately before them in the same department.
#
# **Difficulty:** Hard
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | first_name | department_id | salary | hire_date  |
# |-------------|------------|---------------|--------|------------|
# | 1           | Alice      | 101           | 60000  | 2022-01-01 |
# | 2           | Bob        | 101           | 70000  | 2022-03-01 |
# | 3           | Charlie    | 102           | 80000  | 2022-02-15 |
# | 4           | Diana      | 101           | 65000  | 2022-05-01 |
# | 5           | Eve        | 102           | 85000  | 2022-04-01 |
#
# **Answer:**
#
# ```sql
# SELECT
#     employee_id,
#     first_name,
#     department_id,
#     salary,
#     LAG(salary, 1, 0) OVER (PARTITION BY department_id ORDER BY hire_date) AS previous_employee_salary,
#     salary - LAG(salary, 1, 0) OVER (PARTITION BY department_id ORDER BY hire_date) AS salary_difference_from_prev
# FROM
#     Employees
# ORDER BY
#     department_id, hire_date;
# ```
#
# **Explanation:**
# 1.  **`LAG(salary, 1, 0) OVER (PARTITION BY department_id ORDER BY hire_date)`**: This is a window function called `LAG`.
#     *   `LAG(salary, 1, 0)`:
#         *   `salary`: The column whose value we want from the "previous" row.
#         *   `1`: The offset, meaning we want the value from the immediately preceding row.
#         *   `0`: The default value to return if there is no preceding row (e.g., for the first employee in a department).
#     *   `OVER (PARTITION BY department_id ORDER BY hire_date)`: Defines the window.
#         *   `PARTITION BY department_id`: The `LAG` function will operate independently within each department. The "previous" employee is only considered within the same department.
#         *   `ORDER BY hire_date`: Defines the order within each partition. The "previous" employee is determined by their `hire_date`.
# 2.  **`salary - LAG(...)`**: Subtracts the previous employee's salary from the current employee's salary to get the difference.
#
# ---
#
# #### **Question 11: Customers with More Orders Than Average**
#
# **Question:** Find the names of customers who have placed a total number of orders greater than the overall average number of orders per customer.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name |
# |-------------|------------|
# | 1           | Alice      |
# | 2           | Bob        |
# | 3           | Charlie    |
#
# **`Orders`**
# | order_id | customer_id |
# |----------|-------------|
# | 101      | 1           |
# | 102      | 1           |
# | 103      | 2           |
# | 104      | 1           |
# | 105      | 3           |
#
# **Answer:**
#
# ```sql
# WITH CustomerOrderCounts AS (
#     SELECT
#         customer_id,
#         COUNT(order_id) AS num_orders
#     FROM
#         Orders
#     GROUP BY
#         customer_id
# ),
# AverageOrderCount AS (
#     SELECT
#         AVG(num_orders) AS avg_orders_per_customer
#     FROM
#         CustomerOrderCounts
# )
# SELECT
#     c.first_name,
#     c.last_name,
#     coc.num_orders
# FROM
#     Customers c
# JOIN
#     CustomerOrderCounts coc ON c.customer_id = coc.customer_id
# WHERE
#     coc.num_orders > (SELECT avg_orders_per_customer FROM AverageOrderCount);
# ```
#
# **Explanation:**
# 1.  **`CustomerOrderCounts` CTE**:
#     *   Calculates the `num_orders` for each `customer_id` by grouping `Orders`.
# 2.  **`AverageOrderCount` CTE**:
#     *   Calculates the `AVG(num_orders)` from the `CustomerOrderCounts` CTE, giving us the company-wide average number of orders per customer.
# 3.  **Final `SELECT`**:
#     *   Joins `Customers` with `CustomerOrderCounts` to get customer names and their order counts.
#     *   The `WHERE` clause filters for customers whose `num_orders` is greater than the `avg_orders_per_customer` obtained from the `AverageOrderCount` CTE (used as a subquery).
#     *   This demonstrates using multiple CTEs to break down a complex problem into manageable steps.
#
# ---
#
# #### **Question 12: Sales Trend: Month-over-Month Growth Percentage**
#
# **Question:** Calculate the month-over-month growth percentage in total sales (`total_amount`).
#
# **Difficulty:** Hard
#
# **Sample Data (partial):** (Assume orders from 2023-01 to 2023-03)
#
# **`Orders`**
# | order_id | order_date | total_amount |
# |----------|------------|--------------|
# | 101      | 2023-01-05 | 1000         |
# | 102      | 2023-01-20 | 1500         |
# | 103      | 2023-02-10 | 2000         |
# | 104      | 2023-02-25 | 2500         |
# | 105      | 2023-03-15 | 3000         |
#
# **Answer:**
#
# ```sql
# WITH MonthlySales AS (
#     SELECT
#         DATE_TRUNC('month', order_date) AS sales_month,
#         SUM(total_amount) AS current_month_sales
#     FROM
#         Orders
#     GROUP BY
#         1 -- Shorthand for sales_month
# ),
# LaggedMonthlySales AS (
#     SELECT
#         sales_month,
#         current_month_sales,
#         LAG(current_month_sales, 1, 0) OVER (ORDER BY sales_month) AS previous_month_sales
#     FROM
#         MonthlySales
# )
# SELECT
#     sales_month,
#     current_month_sales,
#     previous_month_sales,
#     CASE
#         WHEN previous_month_sales = 0 THEN NULL -- Handle division by zero for the first month
#         ELSE ((current_month_sales - previous_month_sales) * 100.0 / previous_month_sales)
#     END AS mom_growth_percentage
# FROM
#     LaggedMonthlySales
# ORDER BY
#     sales_month;
# ```
#
# **Explanation:**
# 1.  **`MonthlySales` CTE**:
#     *   Aggregates `total_amount` by month (`DATE_TRUNC('month', order_date)`) to get the total sales for each month.
# 2.  **`LaggedMonthlySales` CTE**:
#     *   Uses the `LAG` window function to retrieve the `current_month_sales` from the *previous* month.
#     *   `LAG(current_month_sales, 1, 0)`: Fetches the value from 1 row before, using 0 as a default if no previous row exists (important for the first month).
#     *   `OVER (ORDER BY sales_month)` ensures the lag is calculated based on chronological month order.
# 3.  **Final `SELECT`**:
#     *   Calculates the month-over-month growth percentage using the formula `((Current Sales - Previous Sales) / Previous Sales) * 100`.
#     *   `CASE WHEN previous_month_sales = 0 THEN NULL`: Crucially handles the first month (where `previous_month_sales` is 0 due to the `LAG` default) to prevent division by zero errors and return `NULL` for the growth percentage as there's no prior month to compare.
#     *   `* 100.0` ensures floating-point division for accurate percentage calculation.
#
# ---
#
# #### **Question 13: Customer Lifetime Value (Simplified)**
#
# **Question:** Calculate a simplified Customer Lifetime Value (CLV) for each customer, defined as the sum of `total_amount` from all their orders. List `customer_id`, `first_name`, `last_name`, and their CLV.
#
# **Difficulty:** Easy
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name | last_name |
# |-------------|------------|-----------|
# | 1           | Alice      | Smith     |
# | 2           | Bob        | Johnson   |
#
# **`Orders`**
# | order_id | customer_id | total_amount |
# |----------|-------------|--------------|
# | 101      | 1           | 100.00       |
# | 102      | 1           | 150.00       |
# | 103      | 2           | 200.00       |
# | 104       | 1          | 50.00        |
#
# **Answer:**
#
# ```sql
# SELECT
#     c.customer_id,
#     c.first_name,
#     c.last_name,
#     COALESCE(SUM(o.total_amount), 0) AS customer_lifetime_value
# FROM
#     Customers c
# LEFT JOIN
#     Orders o ON c.customer_id = o.customer_id
# GROUP BY
#     c.customer_id, c.first_name, c.last_name
# ORDER BY
#     customer_lifetime_value DESC;
# ```
#
# **Explanation:**
# 1.  **`FROM Customers c LEFT JOIN Orders o ON c.customer_id = o.customer_id`**: We use a `LEFT JOIN` from `Customers` to `Orders` to ensure that all customers are included in the result, even those who have placed no orders (their `total_amount` would be `NULL`).
# 2.  **`GROUP BY c.customer_id, c.first_name, c.last_name`**: We group by customer details to aggregate the total amount for each customer. It's good practice to include all non-aggregated columns from the `SELECT` list in the `GROUP BY`.
# 3.  **`COALESCE(SUM(o.total_amount), 0) AS customer_lifetime_value`**:
#     *   `SUM(o.total_amount)` calculates the total order value for each customer.
#     *   `COALESCE(..., 0)` handles customers with no orders: `SUM()` on `NULL` values results in `NULL`, so `COALESCE` replaces that `NULL` with `0`, representing a CLV of zero for those customers.
#
# ---
#
# #### **Question 14: Employees with No Manager (Top Level) and Their Department**
#
# **Question:** List all employees who do not have a manager (i.e., their `manager_id` is NULL) and their respective department names.
#
# **Difficulty:** Easy
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | first_name | manager_id | department_id |
# |-------------|------------|------------|---------------|
# | 1           | John       | NULL       | 101           |
# | 2           | Jane       | 1          | 101           |
# | 3           | Mike       | NULL       | 102           |
#
# **`Departments`**
# | department_id | department_name |
# |---------------|-----------------|
# | 101           | Executive       |
# | 102           | HR              |
#
# **Answer:**
#
# ```sql
# SELECT
#     e.first_name,
#     e.last_name,
#     d.department_name
# FROM
#     Employees e
# JOIN
#     Departments d ON e.department_id = d.department_id
# WHERE
#     e.manager_id IS NULL;
# ```
#
# **Explanation:**
# 1.  **`FROM Employees e JOIN Departments d ON e.department_id = d.department_id`**: An `INNER JOIN` is sufficient here because we are looking for employees who *have* departments and managers are typically associated with departments.
# 2.  **`WHERE e.manager_id IS NULL`**: This filters the results to only include employees whose `manager_id` column is `NULL`, indicating they are at the top of a reporting hierarchy (e.g., a CEO or department head).
#
# ---
#
# #### **Question 15: Find Products Never Ordered**
#
# **Question:** List the names of all products that have never been included in any order.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Products`**
# | product_id | product_name |
# |------------|--------------|
# | 1          | Laptop X     |
# | 2          | Mouse Y      |
# | 3          | Keyboard Z   |
#
# **`Order_Items`**
# | order_item_id | product_id |
# |---------------|------------|
# | 1             | 1          |
# | 2             | 1          |
# | 3             | 2          |
#
# **Answer (using `LEFT JOIN` and `IS NULL`):**
#
# ```sql
# SELECT
#     p.product_name
# FROM
#     Products p
# LEFT JOIN
#     Order_Items oi ON p.product_id = oi.product_id
# WHERE
#     oi.product_id IS NULL;
# ```
#
# **Answer (using `NOT EXISTS`):**
#
# ```sql
# SELECT
#     p.product_name
# FROM
#     Products p
# WHERE NOT EXISTS (
#     SELECT 1
#     FROM Order_Items oi
#     WHERE oi.product_id = p.product_id
# );
# ```
#
# **Answer (using `NOT IN`):**
#
# ```sql
# SELECT
#     p.product_name
# FROM
#     Products p
# WHERE
#     p.product_id NOT IN (SELECT DISTINCT product_id FROM Order_Items);
# ```
#
# **Explanation:**
# 1.  **`LEFT JOIN` and `IS NULL`**:
#     *   `LEFT JOIN Products p` with `Order_Items oi`. This brings all products, and if a product has no matching order items, the `oi.product_id` columns from the `Order_Items` table will be `NULL`.
#     *   `WHERE oi.product_id IS NULL` filters for exactly those products that had no match in `Order_Items`. This is generally a very efficient method.
# 2.  **`NOT EXISTS`**:
#     *   The outer query selects product names.
#     *   `WHERE NOT EXISTS (...)` checks if there is *no* record in `Order_Items` that matches the current product's `product_id`. This is often highly performant.
# 3.  **`NOT IN`**:
#     *   The subquery `(SELECT DISTINCT product_id FROM Order_Items)` gets a list of all `product_id`s that *have* been ordered.
#     *   `WHERE p.product_id NOT IN (...)` then filters for products whose IDs are *not* in that list. Be cautious with `NOT IN` if the subquery can return `NULL` values, as `NOT IN` with `NULL` can lead to unexpected results (no rows returned). In this specific case, `product_id` is a PK/FK, so it shouldn't be `NULL` in `Order_Items`.
#
# ---
#
# #### **Question 16: Top 5 Customers by Total Amount Spent (with Ties)**
#
# **Question:** Find the top 5 customers who have spent the most money (total `total_amount` from all orders). If there are ties for the 5th position, include all customers sharing that rank.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name |
# |-------------|------------|
# | 1           | Alice      |
# | 2           | Bob        |
# | 3           | Charlie    |
# | 4           | Diana      |
# | 5           | Eve        |
# | 6           | Frank      |
# | 7           | Grace      |
#
# **`Orders`**
# | order_id | customer_id | total_amount |
# |----------|-------------|--------------|
# | 101      | 1           | 1000         |
# | 102      | 2           | 900          |
# | 103      | 3           | 850          |
# | 104      | 4           | 800          |
# | 105      | 5           | 750          |
# | 106      | 6           | 750          | -- Tie with customer 5
# | 107      | 7           | 700          |
# | 108      | 1           | 200          |
#
# **Answer:**
#
# ```sql
# WITH CustomerSpend AS (
#     SELECT
#         c.customer_id,
#         c.first_name,
#         c.last_name,
#         SUM(o.total_amount) AS total_spent
#     FROM
#         Customers c
#     JOIN
#         Orders o ON c.customer_id = o.customer_id
#     GROUP BY
#         c.customer_id, c.first_name, c.last_name
# ),
# RankedCustomerSpend AS (
#     SELECT
#         customer_id,
#         first_name,
#         last_name,
#         total_spent,
#         DENSE_RANK() OVER (ORDER BY total_spent DESC) AS rnk
#     FROM
#         CustomerSpend
# )
# SELECT
#     customer_id,
#     first_name,
#     last_name,
#     total_spent
# FROM
#     RankedCustomerSpend
# WHERE
#     rnk <= 5
# ORDER BY
#     total_spent DESC, customer_id;
# ```
#
# **Explanation:**
# 1.  **`CustomerSpend` CTE**:
#     *   Calculates the `total_spent` for each customer by joining `Customers` and `Orders` and summing `total_amount`, then grouping by customer details.
# 2.  **`RankedCustomerSpend` CTE**:
#     *   Applies the `DENSE_RANK()` window function.
#     *   `DENSE_RANK() OVER (ORDER BY total_spent DESC)` assigns a rank to customers based on their `total_spent`, with the highest spender getting rank 1. `DENSE_RANK` assigns the same rank to customers with identical `total_spent` and ensures there are no gaps in the ranking sequence. This is perfect for "top N with ties."
# 3.  **Final `SELECT`**:
#     *   Filters `RankedCustomerSpend` to include only those customers whose `rnk` is 5 or less. Because of `DENSE_RANK`, if there are multiple customers at rank 5 (a tie), all of them will be included.
#     *   Orders the final result for clarity.
#
# ---
#
# #### **Question 17: Find Customers Who Ordered All Products in a Specific Category**
#
# **Question:** Identify customers who have ordered *every* product available in the 'Electronics' category.
#
# **Difficulty:** Hard
#
# **Sample Data (partial):**
#
# **`Customers`**
# | customer_id | first_name |
# |-------------|------------|
# | 1           | Alice      |
# | 2           | Bob        |
# | 3           | Charlie    |
#
# **`Products`**
# | product_id | product_name | category    |
# |------------|--------------|-------------|
# | 1          | Laptop X     | Electronics |
# | 2          | Mouse Y      | Electronics |
# | 3          | Keyboard Z   | Electronics |
# | 4          | Book A       | Books       |
#
# **`Order_Items`**
# | order_item_id | order_id | product_id |
# |---------------|----------|------------|
# | 1             | 101      | 1          | -- Alice ordered Laptop X
# | 2             | 101      | 2          | -- Alice ordered Mouse Y
# | 3             | 102      | 1          | -- Bob ordered Laptop X
# | 4             | 102      | 3          | -- Bob ordered Keyboard Z
# | 5             | 103      | 1          | -- Charlie ordered Laptop X
# | 6             | 103      | 2          | -- Charlie ordered Mouse Y
# | 7             | 103      | 3          | -- Charlie ordered Keyboard Z
# | 8             | 104      | 4          | -- Alice ordered Book A
#
# **Answer:**
#
# ```sql
# WITH ElectronicsProducts AS (
#     SELECT
#         product_id
#     FROM
#         Products
#     WHERE
#         category = 'Electronics'
# ),
# CustomerOrderedElectronics AS (
#     SELECT DISTINCT
#         o.customer_id,
#         oi.product_id
#     FROM
#         Orders o
#     JOIN
#         Order_Items oi ON o.order_id = oi.order_id
#     JOIN
#         ElectronicsProducts ep ON oi.product_id = ep.product_id
# ),
# CustomerProductCounts AS (
#     SELECT
#         customer_id,
#         COUNT(product_id) AS distinct_electronics_products_ordered
#     FROM
#         CustomerOrderedElectronics
#     GROUP BY
#         customer_id
# ),
# TotalElectronicsProducts AS (
#     SELECT
#         COUNT(product_id) AS total_electronics_products
#     FROM
#         ElectronicsProducts
# )
# SELECT
#     c.customer_id,
#     c.first_name,
#     c.last_name
# FROM
#     Customers c
# JOIN
#     CustomerProductCounts cpc ON c.customer_id = cpc.customer_id
# CROSS JOIN
#     TotalElectronicsProducts tep
# WHERE
#     cpc.distinct_electronics_products_ordered = tep.total_electronics_products;
# ```
#
# **Explanation:**
# This is a classic "division" problem in SQL.
# 1.  **`ElectronicsProducts` CTE**: Identifies all `product_id`s that belong to the 'Electronics' category.
# 2.  **`CustomerOrderedElectronics` CTE**:
#     *   Finds distinct pairs of `customer_id` and `product_id` for only those products that are in the 'Electronics' category and have been ordered.
# 3.  **`CustomerProductCounts` CTE**:
#     *   Counts how many *distinct* 'Electronics' products each customer has ordered.
# 4.  **`TotalElectronicsProducts` CTE**:
#     *   Calculates the total number of distinct products in the 'Electronics' category.
# 5.  **Final `SELECT`**:
#     *   Joins `Customers` with `CustomerProductCounts`.
#     *   `CROSS JOIN` with `TotalElectronicsProducts` (it's a single-row result, so `CROSS JOIN` works effectively as a constant).
#     *   The `WHERE` clause is the key: it filters for customers whose count of distinct ordered 'Electronics' products (`cpc.distinct_electronics_products_ordered`) is equal to the total number of 'Electronics' products available (`tep.total_electronics_products`).
#
# ---
#
# #### **Question 18: Analyze Gaps in Order Dates for Each Customer**
#
# **Question:** For each customer, find the maximum number of consecutive days they went without placing an order.
#
# **Difficulty:** Hard
#
# **Sample Data (partial):**
#
# **`Orders`**
# | order_id | customer_id | order_date |
# |----------|-------------|------------|
# | 101      | 1           | 2023-01-01 |
# | 102      | 1           | 2023-01-05 |
# | 103      | 1           | 2023-01-15 |
# | 104      | 2           | 2023-01-02 |
# | 105      | 2           | 2023-01-03 |
# | 106      | 2           | 2023-01-10 |
#
# **Answer:**
#
# ```sql
# WITH CustomerOrderDates AS (
#     SELECT DISTINCT
#         customer_id,
#         order_date
#     FROM
#         Orders
# ),
# LaggedOrderDates AS (
#     SELECT
#         customer_id,
#         order_date,
#         LAG(order_date) OVER (PARTITION BY customer_id ORDER BY order_date) AS previous_order_date
#     FROM
#         CustomerOrderDates
# ),
# DateDifferences AS (
#     SELECT
#         customer_id,
#         order_date,
#         previous_order_date,
#         -- Calculate difference in days. Adjust function for your DB (e.g., DATEDIFF(day, previous_order_date, order_date) for SQL Server)
#         JULIANDAY(order_date) - JULIANDAY(previous_order_date) - 1 AS days_between_orders -- SQLite example
#         -- DATEDIFF(order_date, previous_order_date) - 1 AS days_between_orders -- MySQL example
#         -- (order_date - previous_order_date) - 1 AS days_between_orders -- PostgreSQL example
#     FROM
#         LaggedOrderDates
#     WHERE
#         previous_order_date IS NOT NULL -- Exclude the first order for each customer
# )
# SELECT
#     customer_id,
#     MAX(days_between_orders) AS max_consecutive_days_without_order
# FROM
#     DateDifferences
# GROUP BY
#     customer_id
# ORDER BY
#     customer_id;
# ```
#
# **Explanation:**
# 1.  **`CustomerOrderDates` CTE**:
#     *   Gets a distinct list of `customer_id` and `order_date` to handle cases where a customer might have multiple orders on the same day (we only care about the first order date of the day for gap calculation).
# 2.  **`LaggedOrderDates` CTE**:
#     *   Uses `LAG(order_date)` over `PARTITION BY customer_id ORDER BY order_date` to get the `previous_order_date` for each customer. This sets up the comparison.
# 3.  **`DateDifferences` CTE**:
#     *   Calculates the difference in days between the current `order_date` and the `previous_order_date`.
#     *   `JULIANDAY()` (SQLite) or `DATEDIFF()` (MySQL/SQL Server) or direct date subtraction (PostgreSQL) are used here.
#     *   We subtract `1` because `DATEDIFF` often includes one of the boundary days, and we want the *number of full days* between the orders. (e.g., Jan 1 to Jan 3 is 2 days between).
#     *   `WHERE previous_order_date IS NOT NULL` filters out the first order for each customer, as there's no preceding order to calculate a gap from.
# 4.  **Final `SELECT`**:
#     *   Groups the results by `customer_id` and finds the `MAX(days_between_orders)` to identify the longest gap.
#
# ---
#
# #### **Question 19: Find Employees Hired in the Same Month and Year as Their Manager**
#
# **Question:** List employees who were hired in the same calendar month and year as their direct manager.
#
# **Difficulty:** Medium
#
# **Sample Data (partial):**
#
# **`Employees`**
# | employee_id | first_name | manager_id | hire_date  |
# |-------------|------------|------------|------------|
# | 1           | John       | NULL       | 2022-01-01 |
# | 2           | Jane       | 1          | 2022-01-15 | -- Same month/year as John
# | 3           | Peter      | 1          | 2022-02-01 |
# | 4           | Sarah      | 2          | 2023-05-10 |
# | 5           | Michael    | 4          | 2023-05-20 | -- Same month/year as Sarah
#
# **Answer:**
#
# ```sql
# SELECT
#     e.first_name AS employee_name,
#     m.first_name AS manager_name,
#     e.hire_date AS employee_hire_date,
#     m.hire_date AS manager_hire_date
# FROM
#     Employees e
# JOIN
#     Employees m ON e.manager_id = m.employee_id
# WHERE
#     EXTRACT(YEAR FROM e.hire_date) = EXTRACT(YEAR FROM m.hire_date)
#     AND EXTRACT(MONTH FROM e.hire_date) = EXTRACT(MONTH FROM m.hire_date);
#     -- Alternative for MySQL:
#     -- YEAR(e.hire_date) = YEAR(m.hire_date) AND MONTH(e.hire_date) = MONTH(m.hire_date);
#     -- Alternative for SQL Server:
#     -- YEAR(e.hire_date) = YEAR(m.hire_date) AND MONTH(e.hire_date) = MONTH(m.hire_date);
# ```
#
# **Explanation:**
# 1.  **`FROM Employees e JOIN Employees m ON e.manager_id = m.employee_id`**: This is a **self-join**. We join the `Employees` table with itself.
#     *   `e` represents the employee.
#     *   `m` represents the manager (who is also an employee).
#     *   The join condition `e.manager_id = m.employee_id` correctly links each employee to their direct manager.
# 2.  **`WHERE EXTRACT(YEAR FROM e.hire_date) = EXTRACT(YEAR FROM m.hire_date) AND EXTRACT(MONTH FROM e.hire_date) = EXTRACT(MONTH FROM m.hire_date)`**:
#     *   This condition compares the year and month components of the employee's `hire_date` with their manager's `hire_date`.
#     *   `EXTRACT(YEAR FROM date_column)` and `EXTRACT(MONTH FROM date_column)` are common functions for this (syntax might vary slightly by database, e.g., `YEAR()`/`MONTH()` in MySQL/SQL Server).
#
# ---
#
# #### **Question 20: Performance Optimization & Indexing (Conceptual)**
#
# **Question:** You have a query that is running very slowly:
# `SELECT customer_id, SUM(total_amount) FROM Orders WHERE order_date >= '2023-01-01' GROUP BY customer_id ORDER BY SUM(total_amount) DESC LIMIT 10;`
#
# The `Orders` table has millions of rows. What steps would you take to diagnose and improve its performance?
#
# **Difficulty:** Hard (Conceptual/Practical)
#
# **Answer:**
#
# This question assesses not just SQL syntax but also practical database performance knowledge, which is crucial for a Senior Data Analyst.
#
# **1. Diagnosis Steps:**
#
# *   **`EXPLAIN` / `EXPLAIN ANALYZE` (or `EXPLAIN PLAN` / `SET STATISTICS IO, TIME ON`):** This is the first and most critical step.
#     *   Run `EXPLAIN` (or its equivalent in the specific RDBMS) on the slow query.
#     *   Analyze the output:
#         *   **Table Scan vs. Index Scan:** Is it doing a full table scan on `Orders`? This is likely if no appropriate index is used.
#         *   **Join Order:** If there were joins, is the join order efficient? (Not applicable to this single-table query but relevant generally).
#         *   **Filtering:** How much data is being filtered by the `WHERE` clause?
#         *   **Sorting/Grouping:** Are `GROUP BY` and `ORDER BY` causing large temporary tables or expensive sorts on disk?
#         *   **Cost:** Look at the estimated cost metrics.
#
# **2. Potential Optimizations (Based on common `EXPLAIN` findings):**
#
# *   **Indexing:**
#     *   **On `order_date`:** The `WHERE order_date >= '2023-01-01'` clause is a perfect candidate for an index. A **B-tree index on `Orders.order_date`** would allow the database to quickly jump to the starting date and scan only the relevant portion of the table, avoiding a full table scan.
#     *   **Composite Index (`customer_id`, `order_date`, `total_amount`) or (`order_date`, `customer_id`, `total_amount`):** To further optimize, consider an index that covers the `WHERE`, `GROUP BY`, and `SUM` columns.
#         *   An index on `(order_date, customer_id, total_amount)` (or even just `(order_date, customer_id)` and let the optimizer fetch `total_amount`) could be highly effective. The `order_date` comes first for the `WHERE` clause. Then `customer_id` helps with grouping. If `total_amount` is included (a "covering index"), the database might not even need to touch the main table data for those columns, significantly speeding up the query.
#     *   **Consider index size and write overhead:** While more indexes can speed up reads, they slow down writes (INSERT, UPDATE, DELETE) and consume disk space. I'd weigh the benefits against the costs, particularly for frequently written tables.
#
# *   **Query Rewrite/Refinement:**
#     *   **Subquery/CTE for `SUM`:** For very complex aggregations or if the `SUM` itself is costly, sometimes breaking it into CTEs can aid the optimizer or clarify intent, but less likely to be a silver bullet for this specific query.
#     *   **Data Type Matching:** Ensure `order_date` in the `WHERE` clause has the same data type as the column itself to avoid implicit conversions that can prevent index usage. (e.g., if `order_date` is `DATETIME`, don't compare it to a string without explicit casting if the DB isn't smart enough).
#
# *   **Database Configuration/Hardware:**
#     *   **Memory:** Ensure sufficient memory for sorting and hashing operations, especially for large `GROUP BY`s. If sorts are spilling to disk, that's a major bottleneck.
#     *   **Statistics:** Verify that database statistics are up-to-date. Outdated statistics can mislead the query optimizer into choosing a suboptimal plan.
#     *   **Concurrency:** Is the table heavily locked by other write operations?
#
# **Example of improved query (no change in SQL, but implied index):**
# The SQL remains the same, but the underlying database structure would be optimized.
#
# ```sql
# -- Assuming an index like CREATE INDEX idx_orders_date_cust_amt ON Orders (order_date, customer_id, total_amount); exists
# SELECT
#     customer_id,
#     SUM(total_amount) AS total_spent
# FROM
#     Orders
# WHERE
#     order_date >= '2023-01-01'
# GROUP BY
#     customer_id
# ORDER BY
#     total_spent DESC
# LIMIT 10;
# ```
#
# **Key Takeaways for the Interviewer:**
# The candidate should demonstrate a methodical approach: diagnose first, then apply targeted solutions, understanding the trade-offs of each optimization. For a Senior Data Analyst, simply suggesting an index isn't enough; explaining *why* and *what type* of index, and the impact of the `EXPLAIN` plan, is key.

# %%
with open(
    "sql_interview_guide.txt",
    "w",
    encoding="utf-8"
) as file:

    file.write(interview_questions)

print("Interview Guide Saved")
# Out:
# Interview Guide Saved
